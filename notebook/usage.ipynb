# %% [markdown]
# # Setup and Installation
#
# Before we start, let's install the required libraries and dependencies for this project. We will be using several popular libraries like `sentence-transformers` for machine learning tasks.

# %%
# !pip install -r ../requirements.txt
# !pip install --upgrade sentence-transformers

# %% [markdown]
# # Running the Script
#
# Now that we have installed the necessary packages, let's run the main script (run.py). This script contains the core logic of the project.

# %%
# !python ../src/run.py
# Out:
# Classification complete. Results saved to annotated_company_list.csv.

# %% [markdown]
# # Loading and Displaying Annotated Data
#
# Next, we will load the annotated company list from a CSV file. We will load the data into a pandas DataFrame and display the first 10 rows to inspect its structure.

# %%
import pandas as pd

annotated_df = pd.read_csv('../csv/annotated_company_list.csv')
annotated_df.head(10)
# Out:
#                                          description  \
# 0  Welchcivils is a civil engineering and constru...
# 1  Kyoto Vegetable Specialists Uekamo, also known...
# 2  Loidholdhof Integrative Hofgemeinschaft is a c...
# 3  PATAGONIA Chapa Y Pintura is an auto body shop...
# 4  Stanica WODNA PTTK Swornegacie is a cultural e...
# 5  BIQ Benefícios is a Brazilian company that spe...
# 6  EnvCompli is a company that provides personali...
# 7  Corrugated Beam Form Ltd is a company based in...
# 8  The company specializes in the production and ...
# 9  Indira Caterz And Event Managerzz is a company...
#
#                                        business_tags         sector  \
# 0  ['Construction Services', 'Multi-utilities', '...       Services
# 1  ['Wholesale', 'Dual-task Movement Products', '...  Manufacturing
# 2  ['Living Forms', 'Farm Cafe', 'Fresh Coffee', ...  Manufacturing
# 3  ['Automotive Body Repair Services', 'Interior ...       Services
# ...
